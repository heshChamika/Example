# %% [markdown]
# <a href="https://colab.research.google.com/github/heshChamika/Example/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib

# %%
print(matplotlib.__version__)
# Out:
# 3.7.1

# %%
#draw a line in a diagram from position (0,0) to position (6,50)
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0,6])
ypoints = np.array([0,250])
plt.plot(xpoints,ypoints)
plt.show()

# %%
ypoints = np.array([3,8,1,10])
plt.plot(ypoints, marker = 'o')
plt.show()

# %%
plt.plot(ypoints,linestyle = 'dotted')
plt.show()

# %%
plt.plot(ypoints,linestyle = 'dashed')
plt.show()

# %%
#create labels for a plot
x = np.array([80,85,90,95,100,105,110,115,120,125])
y = np.array([240,250,260,270,280,290,300,310,320,330])

plt.plot(x,y)
plt.xlabel("average pulse")
plt.ylabel("calories burn")
plt.show()

# %%
#creat a title for a plot
x = np.array([80,85,90,95,100,105,110,115,120,125])
y = np.array([240,250,260,270,280,290,300,310,320,330])

plt.plot(x,y)
plt.title("Sports watch data")
plt.xlabel("average pulse")
plt.ylabel("calories burn")
plt.show()

# %%
#creat a title for a plot
x = np.array([80,85,90,95,100,105,110,115,120,125])
y = np.array([240,250,260,270,280,290,300,310,320,330])

plt.plot(x,y)
plt.title("Sports watch data")
plt.xlabel("average pulse")
plt.ylabel("calories burn")
plt.grid()
plt.show()
